# %%
# !pip install pandas

# %%
import pandas as pd

# %%
s= pd.Series([1, 2, 3, 4, 5] )

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1= pd.Series([1, 2, 3, 4, 5],index=["Mussab","Ali","Sara","Zain","Jani"] )

# %%
print(s1)
# Out:
# Mussab    1
# Ali       2
# Sara      3
# Zain      4
# Jani      5
# dtype: int64

# %%
print(s1["Mussab"])
# Out:
# 1

# %%
print(s1.__getitem__("Mussab"))
# Out:
# 1

# %%
print(s1[0])
# Out:
# 1
# /var/folders/70/g_n1x3td79dbdcs4ktrpn2ym0000gn/T/ipykernel_25056/2808656502.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s1[0])

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore
